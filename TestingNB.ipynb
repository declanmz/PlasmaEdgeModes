# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy as scp

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.lines as mlines
import matplotlib.animation as animation
import matplotlib.patches as patches
import matplotlib as mpl
import csv
from tqdm import notebook
import cmath
import json

# %%
class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, complex):
            return {"real": obj.real, "imag": obj.imag}
        return super().default(obj)
    
def as_complex(dct):
    if 'real' in dct and 'imag' in dct:
        return complex(dct['real'], dct['imag'])
    return dct

# %%
# ---------- Define Constants ----------
e = 1.6e-19 #C - charge on electron
m_e = 9.1094e-31 #kg - mass of electron
al = m_e/e #define constant used in matrix
alin = 1/al #al inverse
mu_0 = 4e-7*np.pi #H/m - permeability of free space
ep_0 = 8.854e-12 #F/m - permitivity of free space
c = 3e8 #m/s - speed of light

# %%
import json

data = {'another_dict': {'a': 0, 'b': 1}, 'a_list': [0, 1, 2, 3]}
data["b_list"] = [5,4,3,2,1,0]

data = [3+2j, 2+3j]
file = './ComputationJsons/testing.json' 
with open(file, 'w') as f: 
    json.dump(data, f, cls=ComplexEncoder)

# %%
file = './ComputationJsons/testing.json' 
with open(file, 'r') as f:
    recov_data = json.load(f, object_hook=as_complex)

# %%
recov_data[0].imag
# Out:
# 2.0

# %%
def testfunc():
    return 1,2

# %%
a, b = testfunc()

# %%
mm = 3

def f(mm):
    return mm + 1

# %%
f(mm)
# Out:
# 4

# %%
k0list = np.linspace(-4,4,100)
k0list
# Out:
# array([-4.        , -3.91919192, -3.83838384, -3.75757576, -3.67676768,
#        -3.5959596 , -3.51515152, -3.43434343, -3.35353535, -3.27272727,
#        -3.19191919, -3.11111111, -3.03030303, -2.94949495, -2.86868687,
#        -2.78787879, -2.70707071, -2.62626263, -2.54545455, -2.46464646,
#        -2.38383838, -2.3030303 , -2.22222222, -2.14141414, -2.06060606,
#        -1.97979798, -1.8989899 , -1.81818182, -1.73737374, -1.65656566,
#        -1.57575758, -1.49494949, -1.41414141, -1.33333333, -1.25252525,
#        -1.17171717, -1.09090909, -1.01010101, -0.92929293, -0.84848485,
#        -0.76767677, -0.68686869, -0.60606061, -0.52525253, -0.44444444,
#        -0.36363636, -0.28282828, -0.2020202 , -0.12121212, -0.04040404,
#         0.04040404,  0.12121212,  0.2020202 ,  0.28282828,  0.36363636,
#         0.44444444,  0.52525253,  0.60606061,  0.68686869,  0.76767677,
#         0.84848485,  0.92929293,  1.01010101,  1.09090909,  1.17171717,
# ...

# %%
str(k0list[3]).replace('.','_')
# Out:
# '-3_757575757575758'

# %%
f"{k0list[3]:.5f}".replace('.','_')
# Out:
# '-3_75758'

# %%
directory = '.'
k0mag = k0list[5]
thetadegs = 38

directory + '/EvecData/' + f'{k0mag:.5f}'.replace('.','_') + f'k0_{thetadegs}deg.json'
# Out:
# './EvecData/-3_59596k0_38deg.json'

# %%
list = [3+2j, 2+3j]

# %%
tostr = str([3+2j, 2+3j])

# %%
list(tostr)
# Out:
# ['[',
#  '(',
#  '3',
#  '+',
#  '2',
#  'j',
#  ')',
#  ',',
#  ' ',
#  '(',
#  '2',
#  '+',
#  '3',
#  'j',
#  ')',
#  ']']

# %%
file = './SetupOG/38deg_CutSort.json' 
with open(file, 'r') as f:
    filedata = json.load(f, object_hook=as_complex)

# %%
filedata['Nk']
# Out:
# 2

# %%
filedata['Eavg_list']
# Out:
# [[0.0006209711512017021,
#   0.0006389009124695332,
#   0.0006591264026752518,
#   0.00067772782207718,
#   0.0006985446845018074,
#   0.000720479866789166,
#   0.0007438684409228219,
#   0.0007686183980379206,
#   0.000795616585401307,
#   0.0008256962222804096,
#   0.0008602642651988446,
#   0.0009016850068320557,
#   0.000953871355108565,
#   0.0010231360893904078,
#   0.0011193925881037828,
#   0.0012571913017558095,
#   0.0014554044013192768,
#   0.0017336638338920336,
#   0.0021050654284660766,
#   0.002569307388606839,
#   0.0031151412521167104,
#   0.0037599618613880503,
#   0.005301493775102635,
#   0.010926150879599004,
#   -0.01219642750180885,
#   -0.008800168008486816,
#   -0.010424794240498012,
#   -0.010125883193500256,
#   -0.007520704323212631,
#   -0.008545668133698746,
#   -0.01165041668208963,
#   -0.009773423238392023,
#   -0.010632278485726348,
#   -0.00934767619430164,
#   -0.007991458640895503,
#   -0.009256539596609048,
#   -0.011511868807318325,
# ...

# %%
sda = {
    'a':1,
    'b':None
}

# %%
sda['b'] == None
# Out:
# True

# %%
try:
    if sda['c'] == None:
        print('None')
except:
    pass
print('Continued')
# Out:
# Continued

# %%
arr = np.array([1+2j,2,3-3j,4,5,6,7])
np.where((arr.real > 2) & (arr.real < 6) & (arr.imag != -1))
# Out:
# (array([2, 3, 4], dtype=int64),)

# %%
#Waveguide dispersion
dwg = 6.25e-3
wpwg = 2 * np.pi * 10e9
kpwg = wpwg/c
dispersionload = np.loadtxt("WaveguideDispersion/eps_4.txt")
k0waveguide = dispersionload[:,0]/180 /dwg * np.pi / kpwg
w0waveguide = dispersionload[:,1] * 2 * np.pi * 1e9 / wpwg

# %%
k0waveguide
# Out:
# array([0.        , 0.06666667, 0.23333333, 0.4       , 0.56666667,
#        0.73333333, 0.9       , 1.06666667, 1.23333333, 1.4       ,
#        1.56666667, 1.73333333, 1.9       , 2.06666667, 2.23333333,
#        2.4       ])

# %%
w0waveguide
# Out:
# array([0.        , 0.02679227, 0.09363956, 0.15953756, 0.22362585,
#        0.28512512, 0.34325002, 0.39721107, 0.44624319, 0.48965362,
#        0.52687829, 0.55752481, 0.58138099, 0.59838239, 0.60855179,
#        0.61193465])

# %%
# Define the original data points
x_original = (-k0waveguide)[::-1]
y_original = w0waveguide[::-1]

# Define the new points where we want to interpolate values
x_new = np.linspace(-4, 0, 50)  # 50 points between 0 and 5

# Perform linear interpolation
y_new = np.interp(x_new, x_original, y_original)

# Plot the original data points and the interpolated data
plt.plot(x_original, y_original, 'o', label='Original data')
plt.plot(x_new, y_new, '.', label='Interpolated data')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Interpolation with NumPy')
plt.show()

# %%
asdf = np.array([])
asdf = np.append(asdf,6)

# %%
asdf
# Out:
# array([6.])
